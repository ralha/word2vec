# %%
# !python prep_fairytales.py --urls urls_tales.txt --outdir corpus_base --lower --dedup
# Out:
# Fetched https://www.gutenberg.org/cache/epub/7439/pg7439.txt
# Fetched https://www.gutenberg.org/cache/epub/503/pg503.txt
# Fetched https://www.gutenberg.org/cache/epub/27200/pg27200.txt
# Fetched https://www.gutenberg.org/cache/epub/2591/pg2591.txt
# Fetched https://www.gutenberg.org/cache/epub/17034/pg17034.txt
# Fetched https://www.gutenberg.org/cache/epub/37532/pg37532.txt
# {
#   "stories": 6,
#   "tokens": 792983,
#   "vocab": 19122,
#   "removed_non_english": 0,
#   "generated_at": "2026-02-25T23:48:54.460192Z"
# }
# ✔ Wrote 6 stories to corpus_base\clean
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Tânia\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# c:\Users\Tânia\Work\word2vec\prep_fairytales.py:233: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
# ...

# %%
# !python prep_fairytales.py --urls urls_extended.txt --outdir corpus_ext --lower --dedup
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Tânia\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Traceback (most recent call last):
#   File "c:\Users\Tânia\Work\word2vec\prep_fairytales.py", line 330, in <module>
#     main()
#   File "c:\Users\Tânia\Work\word2vec\prep_fairytales.py", line 312, in main
#     urls = read_urls_file(Path(args.urls))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Tânia\Work\word2vec\prep_fairytales.py", line 55, in read_urls_file
#     with path.open("r", encoding="utf-8") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Tânia\AppData\Local\Programs\Python\Python312\Lib\pathlib.py", line 1013, in open
#     return io.open(self, mode, buffering, encoding, errors, newline)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'urls_extended.txt'
